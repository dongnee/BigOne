# %% [markdown]
# ### View, twitter, 종목토론실 감성 분류
# ##### 수집된 데이터 파일명
# - View : view_카카오035720_info_df.csv
# - twitter : twitter.csv
# - 종목토론 : discuss_2022_2020_df.csv

# %%
# 필요 패키지
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tqdm import tqdm
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# #### 1차. 종목토론실 감성분류 진행

# %%
# 데이터 불러오기
crwal_data = pd.read_csv('crawl_data/discuss_2022_2020_df.csv')
crwal_data
# Out:
#         Unnamed: 0         작성일                                제목  \
# 0                0  2022.04.18           파이낸셜 뉴우스 .한동훈.약점이나 파해처라
# 1                1  2022.04.17              카카오 시총중 지분 가치가 큰데...
# 2                2  2022.04.17                         외화벌이하러나간다
# 3                3  2022.04.17                      주요 국내 기업 적정가
# 4                4  2022.04.17  한동훈 법무장관? 근데 부동산이 불법천지네? 압색좀해야것다
# ...            ...         ...                               ...
# 221492      221492  2020.01.01                           대박이다...
# 221493      221493  2020.01.01                          카카오 믿고간다
# 221494      221494  2020.01.01                     "한국戰 끝낼 때 됐다"
# 221495      221495  2020.01.01      민주당 패거리들이,한국을 중국에 통째로 넘기는구먼.
# 221496      221496  2020.01.01         [코스닥공매도학정은 그무엇으로도 감추지못할것]
#
#                                                       url  공감  비공감
# 0       /item/board_read.naver?code=035720&nid=2192073...   0    0
# 1       /item/board_read.naver?code=035720&nid=2192069...   0    0
# 2       /item/board_read.naver?code=035720&nid=2192065...   0    0
# 3       /item/board_read.naver?code=035720&nid=2192065...   0    0
# 4       /item/board_read.naver?code=035720&nid=2192056...   4    3
# ...                                                   ...  ..  ...
# 221492  /item/board_read.naver?code=035720&nid=1155048...  27    7
# 221493  /item/board_read.naver?code=035720&nid=1155042...   9    3
# 221494  /item/board_read.naver?code=035720&nid=1155030...   6   11
# 221495  /item/board_read.naver?code=035720&nid=1155017...   4   19
# 221496  /item/board_read.naver?code=035720&nid=1155014...   0    1
#
# [221497 rows x 6 columns]
